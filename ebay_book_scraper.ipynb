# %%
import pandas as pd
import numpy as np
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup
#import get to call a get request on the site
from requests import get
import re

# %%
url = 'https://www.ebay.com/sch/i.html?_from=R40&_nkw=books&_sacat=184644&Publication%2520Year=2010%252DNow&_dcat=184644&LH_BIN=1&_pgn=1&rt=nc'

# %%
#get the ebay site listings
response = get(url)
html_soup = BeautifulSoup(response.text, 'html.parser')

# %%
#html_soup

# %%
#create links for pagenation
links =[]
for i in range(1,50):
    links.append('https://www.ebay.com/sch/i.html?_from=R40&_nkw=books&_sacat=184644&Publication%2520Year=2010%252DNow&_dcat=184644&LH_BIN=1&_pgn'+str(i)+'&rt=nc')

# %%
price_list= []
url_list = []
book_titles = []

for link in links:
    response = get(link)
    html_soup = BeautifulSoup(response.text, 'html.parser')
    prices = html_soup.findAll('span', class_ = 's-item__price')
    titles = html_soup.findAll('h3', class_ = 's-item__title')
    urls = html_soup.findAll('a', class_ = 's-item__link')
    for i in range(1,len(prices)):
        price_list.append(prices[i].text)
    for i in range(1,len(titles)):
        book_titles.append(titles[i].text)
    for i in range(1,len(urls)):
        url_list.append(urls[i]['href'])
print(len(url_list))
print(len(book_titles))
print(len(price_list))
# Out:
# 3503
# 3503
# 3503

# %%
url_list[2]
# Out:
# 'https://www.ebay.com/itm/265562942711?epid=219674896&hash=item3dd4c8ecf7%3Ag%3AmKcAAOSwhcZeUoFm&LH_BIN=1'

# %%
url_df = pd.DataFrame(url_list, columns = ['url'])

# %%
df_url = pd.DataFrame(list(zip(url_list, book_titles, price_list)), columns = ['url', 'titles', 'prices'])

# %%
df_url
# Out:
#                                                     url  \
# 0     https://www.ebay.com/itm/181443736804?_trkparm...
# 1     https://www.ebay.com/itm/403491382119?epid=236...
# 2     https://www.ebay.com/itm/265562942711?epid=219...
# 3     https://www.ebay.com/itm/265562945109?epid=236...
# 4     https://www.ebay.com/itm/255400559428?epid=221...
# ...                                                 ...
# 3532  https://www.ebay.com/itm/353149600814?hash=ite...
# 3533  https://www.ebay.com/itm/255400561237?epid=602...
# 3534  https://www.ebay.com/itm/265562635999?epid=150...
# 3535  https://www.ebay.com/itm/254538256739?epid=122...
# 3536  https://www.ebay.com/itm/203841026726?_trkparm...
#
#                                                  titles   prices
# 0     Childrens Books Phonics Set First Little Kinde...   $29.89
# 1     New ListingFinite Mathematics and Its Applicat...   $42.50
# 2     New ListingEssentials of Oceanography, Books a...   $20.87
# ...

# %%
def get_isbn(url):
    response = get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    isbn = soup.findAll('div', class_ = 'ux-layout-section__row')
    return isbn

# %%
len(np.concatenate(df_url['isbn'][0]))
# Out:
# 78

# %%
df_url['isbn'] = df_url['url'][:10].apply(lambda x: get_isbn(x))

# %%
df_url['isbn'].str.split('ISBN', expand= True)
# Out:
#          0
# 0     none
# 1     none
# 2     none
# 3     none
# 4     none
# ...    ...
# 3532   NaN
# 3533   NaN
# 3534   NaN
# 3535   NaN
# 3536   NaN
#
# [3537 rows x 1 columns]

# %%
df_url.isbn.values
# Out:
# array(['none', 'none', 'none', ..., nan, nan, nan], dtype=object)

# %%
df_url['isbn'][1]
# Out:
# 9793

# %%
response = get('https://www.ebay.com/itm/265562942711?epid=219674896&hash=item3dd4c8ecf7%3Ag%3AmKcAAOSwhcZeUoFm&LH_BIN=1'
)
soup = BeautifulSoup(response.text, 'html.parser')
isbn = soup.findAll('div', class_ = 'ux-layout-section__row')
#     isbn_list.append(isbn)
# for i in range(len(isbn)):
#     if 'ISBN:' in isbn[i].text:
#         isbn_list.append(isbn[i].text)

#         else:
#             continue
isbn
# Out:
# [<div class="ux-layout-section__row"> <div class="ux-labels-values col-12 ux-labels-values__column-last-row ux-labels-values--returns" data-testid="ux-labels-values"><div class="ux-labels-values__labels col-3"><div class="ux-labels-values__labels-content"><div><!--F#0--><!--F#f_1--><!--F#1[0]--><span class="ux-textspans"><!--F#f_7[0]-->Returns:<!--F/--></span><!--F/--><!--F/--><!--F/--></div></div></div><div class="ux-labels-values__values col-9"><div class="ux-labels-values__values-content"><!--F#f_7--><!--F#f_8--><div><!--F#0--><!--F#f_1--><!--F#1[0]--><span class="ux-textspans"><!--F#f_7[0]-->30 days returns<!--F/--></span><!--F/--><!--F#1[1]--><span class="ux-textspans"><!--F#f_7[1]--> | <!--F/--></span><!--F/--><!--F#1[2]--><span class="ux-textspans"><!--F#f_7[2]-->Seller pays for return shipping<!--F/--></span><!--F/--><!--F#1[3]--><span class="ux-textspans"><!--F#f_7[3]--> | <!--F/--></span><!--F/--><a data-clientpresentationmetadata='{"operationIdentifier":"SEE_DETAILS_RETURN
# ...

# %%
len(isbn)
# Out:
# 34

# %%
isbn_list = []
url_list_new = []
price_list_new = []
book_titles_new = []
for b, element in enumerate(url_list):
    response = get(url_list[b])
    soup = BeautifulSoup(response.text, 'html.parser')
    isbn = soup.findAll('div', class_ = 'ux-layout-section__row')
#     isbn_list.append(isbn)
    append_to_list =False
    for i in range(len(isbn)):
        if 'ISBN:' in isbn[i].text:
            isbn_list.append(isbn[i].text)
            url_list_new.append(url_list[b])
            price_list_new.append(price_list[b])
            book_titles_new.append(book_titles[b])
        else:
            continue

len(isbn_list)    
len(price_list_new)
len(url_list_new)
len(book_titles_new)
# Out:
# 2970

# %%
print(len(isbn_list))    
print(len(price_list_new))
print(len(url_list_new))
print(len(book_titles_new))
# Out:
# 2970
# 2970
# 2970
# 2970

# %%
# df_isbn = pd.DataFrame(list(zip(isbn_list, book_titles_new,url_list_new, price_list_new)), columns = ['isbn','url', 'titles', 'prices'])

# %%
df_isbn
# Out:
#                                                    isbn  \
# 0              ISBN:9781941489406 Publication Year:2018
# 1              ISBN:9780205979172 Publication Year:2014
# 2                        Subject:Art ISBN:9780134082264
# 3      Condition:Like New: A book that looks new but...
# 4                  ISBN:9780945159766 EAN:9780945159766
# ...                                                 ...
# 2965   Country/Region of Manufacture:United States I...
# 2966   Condition:Like New: A book that looks new but...
# 2967                  ISBN:1119580501 EAN:9781119580508
# 2968                 MPN:Does not apply ISBN:0988973707
# 2969                 MPN:Does not apply ISBN:0738212415
#
#                                                     url  \
# 0     The Essene Gospel of Peace: The Complete 4 Boo...
# 1     New ListingListen to This, Books a la Carte Ed...
# 2        New ListingWorld of Art, A -- Books a la Carte
# 3     New ListingDiscovering the Life Span, Books a ...
# ...

# %%
df_isbn.to_csv('isbn_df')

# %%
isbn_list
# Out:
# ['none',
#  'none',
#  'none',
#  'none',
#  'none',
#  ' ISBN:9781941489406 Publication Year:2018',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  ' ISBN:9780205979172 Publication Year:2014',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  ' Subject:Art ISBN:9780134082264',
#  'none',
#  'none',
#  'none',
#  'none',
# ...

# %%
# first_page = url_list[0]
# response = get(first_page)
# soup = BeautifulSoup(response.text, 'html.parser')
# isbn = soup.findAll('div', class_ = 'ux-layout-section__row')

# %%
isbn[1].text
# Out:
# ' Payments:\xa0\xa0\xa0\xa0\xa0 | See details'

# %%
# isbn_list=[]
# for i in range(len(isbn)):
#         if 'ISBN:' in isbn[i].text:
#             isbn_list.append(isbn[i].text)
            
#         else:
#             continue

# %%
isbn_list
# Out:
# []

# %%
pwd
# Out:
# '/Users/avijames'

# %%
isbn_list
# Out:
# []

# %%
len(isbn_list)
# Out:
# 0

# %%
isbn_list
# Out:
# [' ISBN:9780134464039 Publication Year:2017',
#  ' ISBN:9780134253947 EAN:9780134253947',
#  ' ISBN:9780321977151 EAN:9780321977151',
#  ' ISBN:9780134090412 EAN:9780134090412',
#  ' Language:English Actual ISBN:9781526646675',
#  ' ISBN:9781526640918',
#  ' ISBN:9798750324378',
#  ' Signed:Yes ISBN:9785518657021',
#  " Book Title:Reading History in Children's Books ISBN:9780230278080",
#  ' ISBN:9780078035432 Publication Year:2013',
# ...

# %%
isbn_full_list = []
for line in isbn_list:
    match = re.search('ISBN:(\d+)', line)
    if match:
        isbn_full_list.append(match.group(1))
    else:
        isbn_full_list.append('none')

# %%
isbn_full_list
# Out:
# ['9781941489406',
#  '9780205979172',
#  '9780134082264',
#  '9780134556949',
#  '9780945159766',
#  '0134720385',
#  '9781885010834',
#  '9781526646675',
#  '9781526640918',
#  '9781951577087',
#  '9780615889603',
#  '9780321385178',
#  '9785518657021',
#  '1476740186',
#  '0134686519',
#  '9781681612058',
#  '9781933684468',
#  '9781938113512',
#  '9780989387804',
#  '9781107003392',
#  '9788131533048',
#  '9781935944393',
#  '9781938168376',
#  '9780867198751',
#  '9780321848383',
#  '0812043448',
#  '0134464451',
#  '9781632173133',
#  'none',
#  '9783777430614',
#  '9780134241210',
#  '9781539320647',
#  '9780996746021',
#  '9781623411800',
#  'none',
#  '9781496331519',
#  '1606173847',
#  '9781683440956',
#  '1947314092',
#  '1623921139',
#  '9781319184469',
#  '9781936681488',
#  '9780890517284',
#  '9780194906623',
#  '9780071326469',
#  '9781138121850',
#  '9781623410506',
#  '9781614274216',
#  '9781555819385',
#  '9780578088143',
#  '9780321692535',
#  '9781938245183',
# ...

# %%
len(isbn_full_list)
# Out:
# 2970

# %%
df_isbn[colstocheck] = dftest[colstocheck].replace({'\$':''}, regex = True)
# Out:
# ' ISBN:1476740186 EAN:9781476740188'

# %%
df_2 = pd.DataFrame(isbn_full_list)
df_2.columns=['ISBN']

# %%
df_2.head(14)
# Out:
#                 0
# 0   9780134464039
# 1   9780134253947
# 2   9780321977151
# 3   9780134090412
# 4   9781526646675
# 5   9781526640918
# 6   9798750324378
# 7   9785518657021
# 8   9780230278080
# 9   9780078035432
# 10  9781496029836
# 11  9781250019400
# 12  9780135160428
# 13           none

# %%
df_isbn = pd.DataFrame(list(zip(isbn_full_list, book_titles_new,url_list_new, price_list_new)), columns = ['isbn','url', 'titles', 'prices'])

# %%
df_isbn['prices'] = df_isbn['prices'].replace({'\$':''}, regex = True)

# %%
df_isbn
# Out:
#                isbn                                                url  \
# 0     9781941489406  The Essene Gospel of Peace: The Complete 4 Boo...
# 1     9780205979172  New ListingListen to This, Books a la Carte Ed...
# 2     9780134082264     New ListingWorld of Art, A -- Books a la Carte
# 3     9780134556949  New ListingDiscovering the Life Span, Books a ...
# 4     9780945159766  The Great Books Reading and Discussion Program...
# ...             ...                                                ...
# 2965  9781616697723  American Heart Association AHA ACLS Provider M...
# 2966  9780134011943  New ListingChild Development, Books a la Carte...
# 2967     1119580501  The Official ACT Prep Guide 2019-2020, (Book +...
# 2968     0988973707  The Book on Flipping Houses: How to Buy, Rehab...
# 2969     0738212415  You Can Draw in 30 Days: The Fun, Easy Way to ...
#
#                                                  titles  prices
# ...

# %%
df_isbn.to_csv('isbn_df_2')

# %%
pwd
# Out:
# '/Users/avijames/Dropbox/Mac (2)/Documents/Book_scrape/ebay_book_scraper'

# %%
df_2.columns=['ISBN']

# %%
df_2
# Out:
#                ISBN
# 0     9780134464039
# 1     9780134253947
# 2     9780321977151
# 3     9780134090412
# 4     9781526646675
# ...             ...
# 3072     0134571711
# 3073  9780133027747
# 3074  9781457312199
# 3075  9780486434971
# 3076     0794532829
#
# [3077 rows x 1 columns]
